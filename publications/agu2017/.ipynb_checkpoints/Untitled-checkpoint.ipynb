# %%
import pymicra as pm

# %%
pm.notation
# Out:
# ch4                                                                ch4
# ch4_flux                                                         F_ch4
# ch4_mass_concentration                                        conc_ch4
# ch4_mass_concentration_fluctuations                          conc_ch4'
# ch4_mass_concentration_star                              conc_ch4_star
# ch4_mass_concentration_std                                conc_ch4_std
# ch4_mass_density                                               rho_ch4
# ch4_mass_density_fluctuations                                 rho_ch4'
# ch4_mass_density_star                                     rho_ch4_star
# ch4_mass_density_std                                       rho_ch4_std
# ch4_mass_mixing_ratio                                            r_ch4
# ch4_mass_mixing_ratio_fluctuations                              r_ch4'
# ch4_mass_mixing_ratio_star                                  r_ch4_star
# ...
